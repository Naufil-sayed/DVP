# %% [markdown]
# <a href="https://colab.research.google.com/github/Naufil-sayed/DVP/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Summarizing data statistically
import pandas as pd

data = {
  "Roll no": [6281,6282,6283,6284,6285,6286],
  "Name": ['John Cena','Brock Lesnar','Undertaker','John Cena','Rey Mysterio','Edge'],
  "Marks":[10,20,50,10,98,100]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Roll no          Name  Marks
# 0     6281     John Cena     10
# 1     6282  Brock Lesnar     20
# 2     6283    Undertaker     50
# 3     6284     John Cena     10
# 4     6285  Rey Mysterio     98
# 5     6286          Edge    100

# %%
df.isnull().sum()
df.isnull()
# Out:
#    Roll no   Name  Marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# 5    False  False  False

# %%
df.describe()
# Out:
#            Roll no       Marks
# count     6.000000    6.000000
# mean   6283.500000   48.000000
# std       1.870829   42.142615
# min    6281.000000   10.000000
# 25%    6282.250000   12.500000
# 50%    6283.500000   35.000000
# 75%    6284.750000   86.000000
# max    6286.000000  100.000000

# %%
df.describe(include='object')
# Out:
#              Name
# count           6
# unique          6
# top     John Cena
# freq            1
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
# ...

# %% [markdown]
# # New Section

# %%
df.shape
# Out:
# (6, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  6 non-null      int64
#  1   Name     6 non-null      object
#  2   Marks    6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
df["Marks"]
# Out:
# 0     10
# 1     20
# 2     50
# 3     10
# 4     98
# 5    100
# Name: Marks, dtype: int64

# %%
x=df.corr()
# Out:
# <ipython-input-45-2a9eb634181f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x=df.corr()

# %%
import seaborn as sns
sns.heatmap(x, annot=True,fmt='0.2f',cmap='coolwarm')
df.var(x)
# Out:
# <ipython-input-61-6b1271f1b781>:3: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no       3.5
# Marks      1776.0
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-65-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no    6283.5
# Marks        48.0
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-66-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no       3.5
# Marks      1776.0
# dtype: float64

# %%
df['Marks'].var()
# Out:
# 1776.0

# %%
df.nunique()
# Out:
# Roll no    6
# Name       5
# Marks      5
# dtype: int64

# %%
df.cov()
# Out:
# <ipython-input-68-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#          Roll no   Marks
# Roll no      3.5    64.4
# Marks       64.4  1776.0

# %%
df.value_counts()
# Out:
# Roll no  Name          Marks
# 6281     John Cena     10       1
# 6282     Brock Lesnar  20       1
# 6283     Undertaker    50       1
# 6284     John Cena     10       1
# 6285     Rey Mysterio  98       1
# 6286     Edge          100      1
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of    Roll no          Name  Marks
# 0     6281     John Cena     10
# 1     6282  Brock Lesnar     20
# 2     6283    Undertaker     50
# 3     6284       Cm Punk     10
# 4     6285  Rey Mysterio     98
# 5     6286          Edge    100>

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
import pandas as pd
data=pd.readcsv("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-727115191331> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data=pd.readcsv("workout.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'readcsv'

# %% [markdown]
# # New Section

# %%
import pandas as pd
data = pd.read_csv("/content/Workout.csv")
print (data)
# Out:
#     Body Part   Type of Muscle                      Workout  \
# 0       Chest      Upper Chest       Incline dumbbell press
# 1       Chest      Upper Chest     Incline cable crossovers
# 2       Chest      Upper Chest       Incline dumbbell flyes
# 3       Chest      Lower Chest       Decline dumbbell press
# 4       Chest      Lower Chest     Decline cable crossovers
# 5       Chest      Lower Chest       Decline dumbbell flyes
# 6       Chest  Chest Isolation                  Chest flyes
# 7       Chest  Chest Isolation             Cable crossovers
# 8       Chest  Chest Isolation               Dumbbell flyes
# 9        Back            Upper                     Pull-ups
# 10       Back            Upper                 Barbell rows
# 11       Back            Upper                Dumbbell rows
# 12       Back            Upper            Seated cable rows
# 13       Back            Lower               Bent-over rows
# 14       Back            Lower              Hyperextensions
# ...

# %%
excel=pd.read_excel("/content/Workout.xlsx")
print(excel)
# Out:
#     Body Part   Type of Muscle                      Workout  \
# 0       Chest      Upper Chest       Incline dumbbell press
# 1       Chest      Upper Chest     Incline cable crossovers
# 2       Chest      Upper Chest       Incline dumbbell flyes
# 3       Chest      Lower Chest       Decline dumbbell press
# 4       Chest      Lower Chest     Decline cable crossovers
# 5       Chest      Lower Chest       Decline dumbbell flyes
# 6       Chest  Chest Isolation                  Chest flyes
# 7       Chest  Chest Isolation             Cable crossovers
# 8       Chest  Chest Isolation               Dumbbell flyes
# 9        Back            Upper                     Pull-ups
# 10       Back            Upper                 Barbell rows
# 11       Back            Upper                Dumbbell rows
# 12       Back            Upper            Seated cable rows
# 13       Back            Lower               Bent-over rows
# 14       Back            Lower              Hyperextensions
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('image1.jpg'))
